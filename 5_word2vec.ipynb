# %% [markdown]
# Machine Learning and Deep Learning with Tensorflow
# =============
#
# Word2Vec skip-gram and Continuous Bag of Words
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from itertools import compress
import time

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
start_time = time.time()

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Initialized
# Average loss at step 0: 7.791492
# Nearest to i: arguably, glu, debacle, negroes, wombat, donnie, spelled, ziibi,
# Nearest to while: dxf, medley, quaint, detecting, caucasian, unitas, picchi, widow,
# Nearest to system: agra, frits, jaguar, viciously, establishments, searchlight, josef, improvise,
# Nearest to zero: amide, consulted, fracturing, bata, hi, drivetrain, pentecostalism, origins,
# Nearest to five: excavations, taif, uncompromising, nutrient, impure, zebra, degradation, carib,
# Nearest to not: whose, couture, canis, stol, rise, reckoning, heenan, bribery,
# Nearest to many: concessions, goes, sofa, reverses, flyby, doggy, deflation, revolt,
# Nearest to world: bittering, bona, franchisor, wereman, scarcity, saturday, transferred, emitted,
# Nearest to was: zvi, kilojoules, leftover, modena, dashiell, callahan, andamanese, zen,
# Nearest to he: mascarenes, palahniuk, contributes, caching, lamps, finishes, necklace, rooftop,
# Nearest to time: willie, judith, entrepreneur, geopolitics, livingston, levitt, thermionic, cuyp,
# Nearest to united: whitcomb, rubbish, determinants, yorkist, disagreeing, wins, hills, sindhi,
# Nearest to state: lag, keynesians, blanks, charities, schumpeter, purity, regression, bab,
# Nearest to about: abdicate, etymology, bolster, stricture, devises, sol, espagnole, canonicity,
# Nearest to has: inhibitors, ethical, linger, hieronymus, ther, important, pursues, cleef,
# Nearest to may: ods, backers, ayya, pileser, unaccompanied, wilhelm, beneficiaries, unarable,
# Average loss at step 2000: 4.364495
# Average loss at step 4000: 3.864253
# Average loss at step 6000: 3.788257
# Average loss at step 8000: 3.684091
# Average loss at step 10000: 3.613865
# Nearest to i: debacle, negroes, tib, arguably, guderian, ziibi, compromising, boitano,
# Nearest to while: dor, lipoproteins, dxf, raytheon, bofors, picchi, relocate, hava,
# Nearest to system: agra, frits, jaguar, josef, establishments, eco, viciously, selznick,
# Nearest to zero: nine, seven, six, five, eight, four, three, two,
# Nearest to five: six, eight, four, nine, three, seven, two, zero,
# Nearest to not: it, they, stoic, whose, we, halal, tags, magda,
# Nearest to many: goes, concessions, several, astronomically, cris, parry, cabaret, reverses,
# Nearest to world: honorably, bittering, marginal, caring, issuance, basotho, doubleheader, gog,
# Nearest to was: is, has, were, had, are, by, steve, be,
# Nearest to he: it, they, she, we, never, who, twh, palahniuk,
# Nearest to time: willie, protocol, pod, cuyp, theme, believed, apprenticeship, burial,
# Nearest to united: wife, disagreeing, rubbish, tonne, funky, determinants, sindhi, substances,
# Nearest to state: murbella, refrained, gotland, novel, alibi, lonesome, bids, noree,
# Nearest to about: current, espagnole, zachary, offensive, etymology, hydraulic, exhumed, finally,
# Nearest to has: had, was, is, have, once, can, trails, mohawk,
# Nearest to may: can, would, might, unproven, christensen, explanatory, winged, awful,
# Average loss at step 12000: 3.604565
# Average loss at step 14000: 3.569965
# Average loss at step 16000: 3.410685
# Average loss at step 18000: 3.454411
# Average loss at step 20000: 3.538698
# Nearest to i: ii, tib, debacle, arguably, negroes, guderian, compromising, ziibi,
# Nearest to while: dor, although, lipoproteins, denounced, were, and, chaco, dxf,
# Nearest to system: agra, frits, prolong, selznick, eco, viciously, braddock, jaguar,
# Nearest to zero: five, six, seven, four, nine, three, eight, two,
# Nearest to five: four, seven, six, eight, three, two, zero, nine,
# Nearest to not: also, magda, it, vascular, they, stoic, to, wanting,
# Nearest to many: some, several, other, these, all, cabaret, astronomically, goes,
# Nearest to world: honorably, marginal, electrolytic, taverns, lith, gog, uf, bittering,
# Nearest to was: is, were, has, had, be, been, are, became,
# Nearest to he: it, she, they, who, there, never, we, rails,
# Nearest to time: allosteric, mists, apprenticeship, form, childbearing, vertically, minerals, protocol,
# Nearest to united: disagreeing, tonne, nestorianism, rubbish, funky, karo, north, wife,
# Nearest to state: murbella, government, refrained, noree, neutronic, polarized, equally, bids,
# Nearest to about: etymology, sol, espagnole, routines, doubtless, helmets, inter, mobil,
# Nearest to has: had, have, was, is, once, having, quorum, crocker,
# Nearest to may: can, would, might, could, will, should, must, unproven,
# Average loss at step 22000: 3.503322
# Average loss at step 24000: 3.490252
# Average loss at step 26000: 3.476137
# Average loss at step 28000: 3.481026
# Average loss at step 30000: 3.503463
# Nearest to i: ii, debacle, negroes, tib, compromising, protections, arguably, guderian,
# Nearest to while: although, when, lipoproteins, are, where, after, dor, however,
# Nearest to system: frits, prolong, thus, jaguar, braddock, selznick, viciously, agra,
# Nearest to zero: five, eight, seven, three, six, four, nine, two,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to not: they, vascular, flambards, also, stoic, magda, still, we,
# Nearest to many: some, several, these, all, various, cabaret, most, wifi,
# Nearest to world: gog, issuance, honorably, presentations, united, taverns, salisbury, marginal,
# Nearest to was: is, had, has, were, became, been, being, pseudoscientific,
# Nearest to he: she, it, they, who, there, never, we, chateau,
# Nearest to time: mists, dedham, allosteric, vertically, year, hopefully, protocol, theme,
# Nearest to united: disagreeing, tonne, north, nestorianism, karo, world, dealings, rubbish,
# Nearest to state: murbella, government, noree, refrained, lands, meccan, speleology, grounds,
# Nearest to about: espagnole, over, bannerman, routines, regarding, irrational, current, only,
# Nearest to has: had, have, is, was, having, quorum, crocker, contains,
# Nearest to may: can, would, might, could, will, must, should, cannot,
# Average loss at step 32000: 3.505990
# Average loss at step 34000: 3.493096
# Average loss at step 36000: 3.456288
# Average loss at step 38000: 3.299594
# Average loss at step 40000: 3.426257
# Nearest to i: ii, we, you, debacle, guderian, compromising, negroes, he,
# Nearest to while: although, where, when, after, lipoproteins, were, are, flaubert,
# Nearest to system: frits, eco, systems, selznick, junior, lineages, university, caloric,
# Nearest to zero: five, seven, eight, nine, six, four, three, two,
# Nearest to five: seven, six, three, four, eight, zero, two, nine,
# Nearest to not: they, vascular, usually, it, also, generally, still, flambards,
# Nearest to many: some, several, these, those, various, most, both, such,
# Nearest to world: issuance, assuring, honorably, reticulum, rune, presentations, salisbury, antigua,
# Nearest to was: is, were, became, had, has, been, be, being,
# Nearest to he: she, it, they, who, there, never, intercontinental, i,
# Nearest to time: year, allosteric, dedham, mists, childbearing, apprenticeship, way, compiler,
# Nearest to united: disagreeing, tonne, nestorianism, north, karo, telephones, dealings, remaining,
# Nearest to state: government, lands, noree, stansted, sade, murbella, eulemur, equally,
# Nearest to about: routines, regarding, over, infighting, etymology, roebuck, on, approximately,
# Nearest to has: had, have, was, is, quorum, having, contains, shelter,
# Nearest to may: can, would, will, could, might, should, must, cannot,
# Average loss at step 42000: 3.437693
# Average loss at step 44000: 3.455226
# Average loss at step 46000: 3.448252
# Average loss at step 48000: 3.348109
# Average loss at step 50000: 3.387992
# Nearest to i: ii, we, you, guderian, tib, compromising, ht, he,
# Nearest to while: although, when, where, after, however, if, but, before,
# Nearest to system: systems, selznick, eco, lineages, caloric, worthies, softening, frits,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to five: six, four, eight, seven, three, zero, nine, two,
# Nearest to not: vascular, almost, usually, never, they, we, still, flambards,
# Nearest to many: some, several, these, those, both, various, most, such,
# Nearest to world: issuance, salisbury, antigua, presentations, reward, monoclonal, assuring, reticulum,
# Nearest to was: is, has, became, were, had, been, be, being,
# Nearest to he: she, it, they, who, there, never, we, eventually,
# Nearest to time: year, way, apprenticeship, dedham, allosteric, day, distance, moment,
# Nearest to united: disagreeing, karo, nestorianism, north, tonne, telephones, dealings, encodes,
# Nearest to state: lands, prefect, sade, governor, government, noree, triggers, stansted,
# Nearest to about: regarding, over, rationals, puritan, routines, approximately, etymology, leutze,
# Nearest to has: had, have, was, is, shamanistic, contains, having, does,
# Nearest to may: can, would, should, will, might, could, must, cannot,
# Average loss at step 52000: 3.431835
# Average loss at step 54000: 3.424646
# Average loss at step 56000: 3.439978
# Average loss at step 58000: 3.396591
# Average loss at step 60000: 3.389926
# Nearest to i: ii, we, you, guderian, negroes, compromising, ht, they,
# Nearest to while: although, when, before, if, where, were, however, after,
# Nearest to system: systems, selznick, lineages, frits, eco, softening, linebacker, prolong,
# Nearest to zero: five, four, six, seven, eight, three, nine, two,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to not: still, usually, vascular, almost, generally, we, never, flambards,
# Nearest to many: some, several, various, these, all, both, most, other,
# Nearest to world: assuring, taverns, issuance, gog, largest, stepping, lith, antigua,
# Nearest to was: is, became, had, were, has, being, although, been,
# Nearest to he: she, it, they, there, who, never, we, eventually,
# Nearest to time: way, dedham, sense, moment, year, hopefully, bitters, apprenticeship,
# Nearest to united: disagreeing, nestorianism, karo, tonne, north, encodes, telephones, dealings,
# Nearest to state: lands, government, triggers, speleology, governor, mahagonny, sade, fairest,
# Nearest to about: regarding, over, on, roebuck, puritan, approximately, around, etymology,
# Nearest to has: had, have, was, is, kiosk, contains, shamanistic, having,
# Nearest to may: can, would, might, should, will, could, must, cannot,
# Average loss at step 62000: 3.239657
# Average loss at step 64000: 3.255023
# Average loss at step 66000: 3.401289
# Average loss at step 68000: 3.397934
# Average loss at step 70000: 3.359378
# Nearest to i: ii, we, you, guderian, g, n, negroes, compromising,
# Nearest to while: although, when, where, if, though, before, however, after,
# Nearest to system: systems, frits, selznick, heterosexuality, policy, linebacker, lineages, grampus,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to not: usually, generally, still, almost, never, magda, vascular, typically,
# Nearest to many: some, several, various, all, these, most, both, wifi,
# Nearest to world: assuring, blur, taverns, atmosphere, issuance, uf, lith, electrolytic,
# Nearest to was: is, has, were, had, became, been, be, being,
# Nearest to he: she, it, they, who, there, never, we, eventually,
# Nearest to time: dedham, stains, mists, however, allosteric, moment, bitters, sense,
# Nearest to united: disagreeing, nestorianism, tonne, karo, encodes, supreme, nash, telephones,
# Nearest to state: triggers, lands, city, percival, governor, sade, states, speleology,
# Nearest to about: regarding, over, irrational, on, approximately, easternmost, etymology, roebuck,
# Nearest to has: had, have, was, is, contains, shamanistic, having, congreso,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Average loss at step 72000: 3.369455
# Average loss at step 74000: 3.347821
# Average loss at step 76000: 3.316373
# Average loss at step 78000: 3.351749
# Average loss at step 80000: 3.377335
# Nearest to i: ii, we, you, guderian, g, t, anglicanism, protections,
# Nearest to while: although, when, though, after, however, before, but, if,
# Nearest to system: systems, frits, selznick, heterosexuality, linebacker, lineages, prolong, grampus,
# Nearest to zero: seven, five, six, eight, four, three, nine, two,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Nearest to not: still, generally, never, always, usually, almost, vascular, often,
# Nearest to many: some, several, various, most, these, both, all, few,
# Nearest to world: monoclonal, issuance, uf, assuring, taverns, blur, cold, stepping,
# Nearest to was: is, were, became, has, had, being, been, be,
# Nearest to he: she, it, they, there, who, we, never, eventually,
# Nearest to time: dedham, mists, apprenticeship, year, division, castrato, way, upland,
# Nearest to united: disagreeing, nestorianism, tonne, encodes, impetuous, karo, nash, telephones,
# Nearest to state: city, usa, governor, transitioned, government, states, lands, triggers,
# Nearest to about: approximately, regarding, over, easternmost, etymology, nearly, roebuck, spotting,
# Nearest to has: had, have, is, was, contains, shamanistic, although, does,
# Nearest to may: would, can, might, could, will, should, must, cannot,
# Average loss at step 82000: 3.404159
# Average loss at step 84000: 3.410558
# Average loss at step 86000: 3.390892
# Average loss at step 88000: 3.354900
# Average loss at step 90000: 3.364568
# Nearest to i: ii, we, guderian, you, g, mbox, protections, ht,
# Nearest to while: although, when, though, after, were, during, before, but,
# Nearest to system: systems, frits, selznick, heterosexuality, light, process, prolong, minus,
# Nearest to zero: seven, five, six, eight, four, nine, three, u,
# Nearest to five: four, seven, eight, three, six, nine, zero, two,
# Nearest to not: still, generally, almost, never, vascular, probably, ultimately, nor,
# Nearest to many: some, several, various, these, all, most, numerous, those,
# Nearest to world: taverns, maldivian, civil, stepping, assuring, issuance, monoclonal, uf,
# Nearest to was: is, had, were, became, has, been, be, roshan,
# Nearest to he: she, it, they, there, who, never, we, but,
# Nearest to time: dedham, year, if, success, compiler, infty, bitters, castrato,
# Nearest to united: disagreeing, newbies, encodes, nestorianism, tonne, karo, huron, impetuous,
# Nearest to state: city, triggers, usa, government, states, transitioned, eu, governor,
# Nearest to about: regarding, etymology, spotting, easternmost, concerning, roebuck, approximately, puritan,
# Nearest to has: had, have, is, was, since, contains, having, shamanistic,
# Nearest to may: can, could, should, might, must, would, will, cannot,
# Average loss at step 92000: 3.394746
# Average loss at step 94000: 3.249299
# Average loss at step 96000: 3.360220
# Average loss at step 98000: 3.246779
# Average loss at step 100000: 3.352806
# Nearest to i: we, ii, you, guderian, they, g, mbox, comnenus,
# Nearest to while: although, when, though, if, before, but, where, are,
# Nearest to system: systems, process, frits, baikal, selznick, heterosexuality, softening, warfare,
# Nearest to zero: five, four, seven, eight, six, three, nine, two,
# Nearest to five: seven, four, six, eight, three, two, zero, nine,
# Nearest to not: never, almost, still, generally, nor, they, always, magda,
# Nearest to many: some, several, all, various, these, few, numerous, those,
# Nearest to world: issuance, monoclonal, uf, game, reticulum, salisbury, occupies, tsang,
# Nearest to was: is, became, had, has, were, been, boldly, egotistical,
# Nearest to he: she, it, they, there, who, we, never, successfully,
# Nearest to time: year, way, kind, dedham, castrato, reason, boolean, sense,
# Nearest to united: disagreeing, newbies, nestorianism, encodes, karo, lender, supreme, tonne,
# Nearest to state: city, governor, states, pellet, triggers, government, transitioned, rain,
# Nearest to about: regarding, etymology, irrational, approximately, routines, puritan, roebuck, easternmost,
# Nearest to has: had, have, was, is, since, having, shamanistic, extrapolated,
# Nearest to may: can, could, should, might, will, would, must, cannot,
# --- 386.245421171 seconds ---

# %%
print(final_embeddings[0])
# Out:
# [-0.02639471  0.07248329  0.01637082 -0.14415301 -0.08583918  0.02833727
#   0.0308374   0.05748058  0.14241347  0.03762036  0.14408922  0.0358328
#  -0.15088575 -0.16084361  0.01701901  0.09889431  0.18149093  0.03734218
#  -0.13032624  0.1618754   0.04054736 -0.04140795 -0.05976616 -0.09432723
#  -0.05704527 -0.0957578  -0.07485098  0.07295363 -0.07036026  0.03425987
#   0.0601876  -0.2575523   0.12760527  0.02819455 -0.0230315  -0.08810995
#  -0.09548915  0.10977466 -0.03270362 -0.10196331  0.01457498 -0.0579708
#  -0.05973541  0.02465197  0.01015045  0.05310899 -0.03595276 -0.11520527
#   0.02488281  0.05624504 -0.08996534  0.0366588   0.06824782 -0.15706213
#   0.17256808  0.10388703 -0.02087691  0.05994164  0.02111592 -0.04690418
#   0.07389382 -0.03394496 -0.06649502 -0.17389008 -0.02403315  0.01472231
#  -0.04016695 -0.12994353  0.07528878 -0.05639168 -0.11318451 -0.06204212
#  -0.07924428  0.14032578 -0.06750895 -0.03252327 -0.04430053 -0.01751792
#   0.05342625  0.00448026  0.0484494   0.04151602  0.12103902  0.06468543
#  -0.12927236  0.05364063  0.01611443  0.06037038  0.08728348  0.09308168
#  -0.11377432 -0.0631737   0.01868707  0.19466931 -0.09585872  0.12176033
#   0.0335288  -0.00878077  0.13346086 -0.06355537 -0.02476389  0.06377686
#   0.02947204  0.02531927 -0.06253733  0.00441164  0.00667302 -0.02772413
#   0.14459199  0.04773938  0.12765028 -0.00981996  0.05504688  0.00184966
#  -0.28415951 -0.05016142 -0.15308809 -0.04063812 -0.15958956 -0.05019651
#   0.01614334  0.01383407 -0.09279984 -0.01827063  0.0050331  -0.01691898
#  -0.05031699  0.04952844]

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# slightly modify the word2vec batch creation to use the sum of vectors of surrounding words
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    '''
    Batch generator for CBOW (Continuous Bag of Words)
    Parameters
    ----------
    data: list of index of words
    batch_size: number of words in each mini-batch
    num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
    skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
    '''
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        mask = [1] * span
        mask[skip_window] = 0 
        batch[i, :] = list(compress(buffer, mask)) # all surrounding words
        labels[i, 0] = buffer[skip_window] # the word at the center 
        buffer.append(data[data_index]) # data is defined above
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])
    
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embed, 1),
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
    
    #train_prediction = tf.nn.softmax(tf.matmul(tf.reduce_sum(embed, 1), 
                                               #tf.transpose(softmax_weights)) + softmax_biases)

# %%
num_steps = 100001
start_time = time.time()

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        #_, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            #print('Accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
            
    final_embeddings = normalized_embeddings.eval()

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Initialized
# Average loss at step 0: 7.896859
# Nearest to UNK: nino, prevent, hurdler, rw, distributors, badminton, xi, motley,
# Nearest to more: scarred, romans, accountancy, spoofing, bradford, besieged, frameworks, oust,
# Nearest to used: hal, froissart, aj, alfv, hacked, conscripted, unless, drifting,
# Nearest to state: heterochromatin, culminates, drained, hearers, noel, removed, abbotsford, possibilities,
# Nearest to all: figurines, bored, incisors, brute, kanembu, mean, historical, skates,
# Nearest to also: pete, xxvi, hustler, dishonesty, entailed, fretless, technical, wives,
# Nearest to from: kim, supply, lussac, strangelove, cleves, famed, fools, permeable,
# Nearest to see: cddb, neglecting, neville, erythromycin, aegisthus, aveiro, cyanide, perfective,
# Nearest to during: auld, kano, interface, artificial, trades, welcome, poulsen, gingrich,
# Nearest to and: arithmetica, ablaze, clooney, alaska, isotropic, defer, mormons, videotaped,
# Nearest to they: robbers, keynes, parcham, crioulo, amboise, isbn, formic, commissioning,
# Nearest to after: infinitely, infty, finitely, souvenir, deutschen, antares, brokers, tavola,
# Nearest to four: godlike, millennia, scumm, montreux, enhancements, spit, iwo, mercalli,
# Nearest to when: pejorative, suspensions, bmx, quintet, hellenistic, khomeini, dunwich, rashad,
# Nearest to b: sacerdotal, phoned, adverbs, postmodern, fermenting, involving, lottery, distillers,
# Nearest to such: schoenberg, evagrius, hillsdale, kubitzki, arnold, accepting, meiosis, ruskin,
# Average loss at step 2000: 4.096829
# Average loss at step 4000: 3.558181
# Average loss at step 6000: 3.392334
# Average loss at step 8000: 3.247176
# Average loss at step 10000: 3.182802
# Nearest to UNK: baffin, dairy, monody, shivaji, fuego, exilic, salesman, zeus,
# Nearest to more: less, most, bradford, pitch, delaunay, slaughters, archetypical, kindred,
# Nearest to used: known, hal, regarded, squarepants, aj, conscripted, oration, enki,
# Nearest to state: heterochromatin, drained, possibilities, hearers, disengagement, culminates, peers, states,
# Nearest to all: heizei, incisors, many, these, some, kami, feinstein, skates,
# Nearest to also: often, which, already, who, now, csp, not, auc,
# Nearest to from: in, into, mash, between, for, kim, rentals, keynesians,
# Nearest to see: neville, neglecting, cyanide, performances, celia, symonds, sides, rendered,
# Nearest to during: in, lomo, kano, isps, studying, auld, uns, herders,
# Nearest to and: or, catalysis, musab, fubar, inflammatory, aha, arrayed, but,
# Nearest to they: he, there, we, you, she, then, formalist, who,
# Nearest to after: brilliant, undiscovered, tavola, instants, before, for, westphalian, electrolysis,
# Nearest to four: three, eight, five, six, two, seven, nine, zero,
# Nearest to when: lysine, duncan, biblical, volkssturm, rashad, joshua, dect, thebaid,
# Nearest to b: d, intermixed, coining, gting, foreskin, cubans, delinquency, objections,
# Nearest to such: well, ether, incredibly, regarded, these, nearer, schoenberg, evagrius,
# Average loss at step 12000: 3.212528
# Average loss at step 14000: 3.155843
# Average loss at step 16000: 3.184005
# Average loss at step 18000: 3.130213
# Average loss at step 20000: 2.992091
# Nearest to UNK: bergson, bogdanovich, dipole, stradella, e, pushkin, l, vi,
# Nearest to more: less, most, very, bradford, so, brzezinski, too, other,
# Nearest to used: known, regarded, found, classified, considered, written, required, able,
# Nearest to state: states, national, brushing, government, northampton, us, goodnight, mom,
# Nearest to all: heizei, secaucus, every, many, any, sauk, these, several,
# Nearest to also: often, which, now, generally, still, who, already, not,
# Nearest to from: into, through, between, punctuated, by, lussac, mash, since,
# Nearest to see: neglecting, neville, but, cyanide, celia, draw, symonds, include,
# Nearest to during: in, at, after, before, lomo, wha, blot, studying,
# Nearest to and: or, progressions, but, while, ribose, needing, catalysis, weavers,
# Nearest to they: we, there, he, you, it, these, she, who,
# Nearest to after: before, when, following, during, for, brilliant, slings, instants,
# Nearest to four: five, six, three, eight, seven, nine, zero, two,
# Nearest to when: before, if, after, where, since, with, by, qwerty,
# Nearest to b: d, catalogs, objections, coining, foreskin, governorship, cubans, humbucker,
# Nearest to such: well, these, ether, known, many, regarded, some, valdemar,
# Average loss at step 22000: 3.076360
# Average loss at step 24000: 3.039193
# Average loss at step 26000: 3.004977
# Average loss at step 28000: 3.028812
# Average loss at step 30000: 3.011207
# Nearest to UNK: bergson, smith, iai, gr, grapple, circumvented, vocal, grin,
# Nearest to more: less, most, very, too, bradford, other, highly, extremely,
# Nearest to used: known, found, required, written, regarded, considered, designed, able,
# Nearest to state: states, government, national, heterochromatin, drained, press, northampton, brushing,
# Nearest to all: every, these, some, both, many, various, any, mouths,
# Nearest to also: now, still, often, never, which, sometimes, actually, generally,
# Nearest to from: into, through, since, after, merdeka, within, soi, during,
# Nearest to see: but, neglecting, neville, include, defectors, barrel, refer, cyanide,
# Nearest to during: after, in, when, before, at, under, throughout, meher,
# Nearest to and: or, but, however, wr, catalysis, sourced, progressions, than,
# Nearest to they: we, there, you, he, she, these, then, it,
# Nearest to after: before, when, during, while, following, since, brilliant, from,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to when: if, before, after, where, although, while, during, since,
# Nearest to b: d, coining, cubans, delinquency, nationality, motto, poem, nautilus,
# Nearest to such: these, well, known, regarded, ether, many, turtle, certain,
# Average loss at step 32000: 2.828870
# Average loss at step 34000: 2.954870
# Average loss at step 36000: 2.947490
# Average loss at step 38000: 2.942440
# Average loss at step 40000: 2.929980
# Nearest to UNK: baffled, swinging, kutch, gojira, lyrical, joseph, cyclic, minos,
# Nearest to more: less, most, very, too, extremely, highly, smaller, better,
# Nearest to used: known, found, written, required, responsible, represented, designed, regarded,
# Nearest to state: states, press, national, northampton, government, trailing, kuril, city,
# Nearest to all: various, every, both, any, many, sauk, some, mouths,
# Nearest to also: now, still, often, actually, which, sometimes, never, usually,
# Nearest to from: through, into, during, by, after, soi, despite, within,
# Nearest to see: neville, include, refer, neglecting, braganza, auto, defectors, psych,
# Nearest to during: after, in, despite, throughout, before, when, from, following,
# Nearest to and: or, but, while, catalysis, sourced, fools, nano, progressions,
# Nearest to they: we, there, he, you, she, it, mentally, these,
# Nearest to after: before, during, when, while, following, since, brilliant, pipelined,
# Nearest to four: five, six, three, eight, seven, nine, zero, two,
# Nearest to when: before, if, after, during, while, where, by, then,
# Nearest to b: d, tacitly, lechuck, partement, humbucker, col, m, superpowers,
# Nearest to such: well, these, known, regarded, seen, nearer, ether, certain,
# Average loss at step 42000: 2.949842
# Average loss at step 44000: 2.959153
# Average loss at step 46000: 2.908374
# Average loss at step 48000: 2.865631
# Average loss at step 50000: 2.846896
# Nearest to UNK: mrs, vannevar, le, von, callisthenes, martin, agassi, stared,
# Nearest to more: less, most, very, smaller, extremely, better, longer, larger,
# Nearest to used: known, written, required, found, available, employed, held, designed,
# Nearest to state: states, government, press, city, deputies, trailing, northampton, pastoral,
# Nearest to all: various, many, both, several, every, any, mouths, some,
# Nearest to also: actually, now, sometimes, often, still, usually, never, generally,
# Nearest to from: through, into, during, in, within, aidan, between, without,
# Nearest to see: refer, include, includes, auto, neville, psych, opiate, references,
# Nearest to during: in, after, despite, when, throughout, before, from, while,
# Nearest to and: or, aonb, while, nano, including, gonads, american, sabers,
# Nearest to they: we, there, he, you, she, it, these, thurston,
# Nearest to after: before, when, during, while, until, following, since, without,
# Nearest to four: eight, seven, six, five, three, nine, two, zero,
# Nearest to when: before, if, after, where, during, while, though, although,
# Nearest to b: d, lechuck, mersenne, tacitly, stabbed, col, icosidodecahedron, humbucker,
# Nearest to such: known, well, certain, regarded, these, many, follows, ether,
# Average loss at step 52000: 2.887137
# Average loss at step 54000: 2.867244
# Average loss at step 56000: 2.859672
# Average loss at step 58000: 2.754476
# Average loss at step 60000: 2.825502
# Nearest to UNK: noncommercial, franz, l, tennyson, garret, recluse, bogdanovich, asymptomatic,
# Nearest to more: less, most, very, extremely, smaller, too, quite, highly,
# Nearest to used: known, required, employed, designed, regarded, written, represented, described,
# Nearest to state: states, government, press, commemorations, merrick, deputies, northampton, bertolt,
# Nearest to all: various, both, every, any, many, several, outside, some,
# Nearest to also: actually, still, now, often, sometimes, never, generally, usually,
# Nearest to from: into, through, during, by, within, between, in, tro,
# Nearest to see: refer, include, includes, neglecting, hydraulics, references, according, links,
# Nearest to during: in, after, despite, when, within, throughout, until, while,
# Nearest to and: or, but, although, however, burke, anna, sourced, progressions,
# Nearest to they: we, he, you, there, she, it, i, thurston,
# Nearest to after: before, when, during, following, while, without, despite, if,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to when: if, where, after, before, during, although, though, while,
# Nearest to b: d, lechuck, tacitly, c, l, tract, x, stabbed,
# Nearest to such: certain, known, well, these, regarded, nearer, parasite, many,
# Average loss at step 62000: 2.833944
# Average loss at step 64000: 2.771910
# Average loss at step 66000: 2.763391
# Average loss at step 68000: 2.714752
# Average loss at step 70000: 2.787008
# Nearest to UNK: roxbury, kaiser, untenable, erich, paz, eschew, shivaji, pneumonia,
# Nearest to more: less, most, very, quite, extremely, greater, highly, too,
# Nearest to used: required, known, employed, seen, considered, referred, responsible, found,
# Nearest to state: government, states, press, situation, gasses, territory, teodoro, city,
# Nearest to all: both, various, many, sauk, these, bead, every, several,
# Nearest to also: now, actually, never, still, often, sometimes, generally, usually,
# Nearest to from: through, during, kabbalah, rips, after, between, into, across,
# Nearest to see: references, includes, refer, include, but, mcleod, neville, according,
# Nearest to during: despite, in, after, throughout, before, when, following, since,
# Nearest to and: or, but, although, though, including, however, progressions, sourced,
# Nearest to they: we, he, you, there, she, it, these, cryptanalytic,
# Nearest to after: before, during, when, while, following, despite, without, since,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to when: if, where, after, before, though, during, while, although,
# Nearest to b: d, tacitly, cloak, delinquency, wedgwood, tract, pertwee, circumstance,
# Nearest to such: known, well, follows, regarded, certain, described, seen, defined,
# Average loss at step 72000: 2.800062
# Average loss at step 74000: 2.645789
# Average loss at step 76000: 2.804058
# Average loss at step 78000: 2.826140
# Average loss at step 80000: 2.776038
# Nearest to UNK: ne, pneumonia, ddd, van, baffin, jay, wavering, vy,
# Nearest to more: less, very, most, extremely, highly, smaller, quite, larger,
# Nearest to used: known, required, regarded, responsible, employed, referred, described, applied,
# Nearest to state: states, government, national, press, gasses, territory, deciding, ogle,
# Nearest to all: both, various, many, every, any, some, several, most,
# Nearest to also: often, now, still, never, actually, sometimes, usually, currently,
# Nearest to from: through, into, across, during, via, within, rips, before,
# Nearest to see: include, references, includes, refer, according, saw, angela, list,
# Nearest to during: in, after, despite, when, before, throughout, including, until,
# Nearest to and: or, including, but, although, however, sourced, progressions, of,
# Nearest to they: we, you, he, there, she, i, these, it,
# Nearest to after: before, during, when, without, for, following, despite, while,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to when: if, before, after, though, where, during, although, while,
# Nearest to b: d, c, tacitly, l, tract, stockpiling, h, negligent,
# Nearest to such: well, certain, known, regarded, these, follows, act, many,
# Average loss at step 82000: 2.665724
# Average loss at step 84000: 2.768965
# Average loss at step 86000: 2.734890
# Average loss at step 88000: 2.751905
# Average loss at step 90000: 2.734892
# Nearest to UNK: noncommercial, ne, roxbury, wayne, orientalis, sharm, brown, irregulars,
# Nearest to more: less, most, highly, very, extremely, quite, longer, greater,
# Nearest to used: required, employed, known, designed, described, regarded, responsible, released,
# Nearest to state: states, government, city, national, territory, redundant, castell, colosseum,
# Nearest to all: both, various, every, many, some, any, gentrification, several,
# Nearest to also: now, still, often, never, actually, always, sometimes, generally,
# Nearest to from: into, through, across, during, including, via, after, before,
# Nearest to see: include, references, includes, refer, but, mcleod, list, according,
# Nearest to during: in, after, throughout, despite, at, including, within, before,
# Nearest to and: or, sourced, including, amass, but, needing, inflammatory, midgard,
# Nearest to they: we, you, he, there, she, i, it, these,
# Nearest to after: before, during, without, despite, when, while, following, upon,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to when: if, although, though, where, while, before, after, during,
# Nearest to b: d, c, f, l, k, ribeira, tacitly, stockpiling,
# Nearest to such: well, these, known, follows, certain, regarded, act, jerseys,
# Average loss at step 92000: 2.683637
# Average loss at step 94000: 2.725572
# Average loss at step 96000: 2.698736
# Average loss at step 98000: 2.365708
# Average loss at step 100000: 2.401078
# Nearest to UNK: noncommercial, anesthetics, inversely, scholar, circumvented, tennyson, qaida, brood,
# Nearest to more: less, most, very, highly, extremely, rather, quite, longer,
# Nearest to used: employed, required, referred, known, applied, designed, regarded, released,
# Nearest to state: states, government, national, territory, city, fueled, azo, deputies,
# Nearest to all: both, various, many, several, every, some, each, taoism,
# Nearest to also: still, actually, now, often, never, currently, which, sometimes,
# Nearest to from: across, through, rips, via, into, after, jinx, by,
# Nearest to see: include, includes, references, mcleod, refer, external, according, neville,
# Nearest to during: despite, in, after, at, when, before, throughout, following,
# Nearest to and: or, but, though, nor, prescriptive, salm, sourced, humpback,
# Nearest to they: we, he, there, you, she, i, it, thurston,
# Nearest to after: before, during, when, following, despite, without, while, for,
# Nearest to four: five, eight, seven, six, three, nine, two, zero,
# Nearest to when: if, though, before, where, after, although, while, during,
# Nearest to b: d, delinquency, shapur, intermixed, jacques, governorship, zeno, monorails,
# Nearest to such: well, these, known, certain, many, regarded, follows, seen,
# --- 422.966216087 seconds ---

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# It is not obvious what the differences are between CBOW and skipgram are difficult to notice by looking at the scatter plots. Here a couple of other differences that I have found:
# 1. skipgram is about 10% faster to train than CBOW
# 2. CBOW predicts center word from sum of surrounding word vectors instead of predicting surrounding single words from center word as in skipgram model
# 3. CBOW should have better accuracy for words that are frequently found in the data
